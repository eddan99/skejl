# %% [markdown]
# # Steg 1: Generera Realistiskt Dataset
#
# **Target: CTR (Click-Through Rate)**
# CTR = klick / visningar. Bestäms av bilden – inte pris eller kassa.
#
# **Vad vi bygger här:**
# En formel där product features + image settings → ett trovärdigt CTR-värde med realistiska mönster och lite brus.

# %%
import json
import random
import pandas as pd
from pathlib import Path

random.seed(42)

OUTPUT_PATH = Path('../../data/input/ctr_dataset.json')
print(f"Output: {OUTPUT_PATH.resolve()}")
# Out:
# Output: /Users/edvinrunhellen/Documents/MAI24HA/Exjobb/skejl/data/input/ctr_dataset.json

# %% [markdown]
# ## Taxonomier

# %%
GARMENT_TYPES = [
    'hoodie', 'zip-up hoodie', 'sweatshirt',
    't-shirt', 'polo',
    'jacket', 'coat', 'windbreaker', 'parka',
    'jeans', 'trousers', 'shorts'
]
COLORS = [
    'black', 'white', 'dark grey', 'light grey',
    'dark', 'dark brown', 'navy', 'burgundy', 'olive', 'forest green',
    'light', 'beige', 'cream', 'sand', 'light blue',
    'colorful', 'red', 'yellow', 'orange', 'green', 'blue', 'pink', 'purple'
]
FITS          = ['loose', 'regular', 'tight', 'oversized']
GENDERS       = ['male', 'female', 'unisex']

STYLES      = ['urban_outdoor', 'studio_minimal', 'lifestyle_indoor',
               'casual_lifestyle', 'streetwear', 'lifestyle_outdoor']
LIGHTINGS   = ['golden_hour', 'studio', 'natural', 'overcast', 'dramatic']
BACKGROUNDS = ['studio_white', 'studio_grey', 'neutral_wall',
               'urban_street', 'graffiti_wall', 'nature_outdoor',
               'park', 'busy_pattern']
POSES       = ['walking', 'standing', 'action', 'sitting', 'dynamic', 'casual']
EXPRESSIONS = ['confident', 'serious', 'smiling', 'neutral', 'focused']
ANGLES      = ['front', 'side', '3/4', 'back']

# Color groups for CTR formula
DARK_COLORS  = {'dark', 'black', 'dark grey', 'dark brown', 'navy', 'burgundy', 'olive', 'forest green'}
LIGHT_COLORS = {'light', 'white', 'light grey', 'light blue', 'beige', 'cream', 'sand'}
COLORFUL_COLORS = {'colorful', 'red', 'yellow', 'orange', 'green', 'blue', 'pink', 'purple'}

# %% [markdown]
# ## CTR-formel
#
# Tre faktorer styr CTR för en produktbild:
# 1. **Visual impact** – syns produkten tydligt?
# 2. **Context match** – matchar stilen produkten?
# 3. **Emotional appeal** – skapar bilden aspiration?

# %%
def calculate_ctr(garment_type, color, fit, gender,
                  style, lighting, background,
                  pose, expression, angle,
                  noise_level=0.006):

    # 1. Bas-CTR per plaggtyp
    base = {
        'hoodie': 0.028, 'zip-up hoodie': 0.027, 'sweatshirt': 0.026,
        't-shirt': 0.032, 'polo': 0.030,
        'jacket': 0.030, 'coat': 0.029, 'windbreaker': 0.028, 'parka': 0.027,
        'jeans': 0.022, 'trousers': 0.024, 'shorts': 0.025,
    }
    ctr = base.get(garment_type, 0.028)

    # 2. Ljus + färg-synergi (visual impact) — grouped by color category
    is_dark     = color in DARK_COLORS
    is_light    = color in LIGHT_COLORS
    is_colorful = color in COLORFUL_COLORS

    if is_dark and lighting == 'golden_hour':    ctr += 0.010
    elif is_dark and lighting == 'dramatic':     ctr += 0.008
    elif is_dark and lighting == 'studio':       ctr += 0.004
    elif is_dark and lighting == 'overcast':     ctr -= 0.005
    elif is_light and lighting == 'studio':      ctr += 0.009
    elif is_light and lighting == 'natural':     ctr += 0.007
    elif is_light and lighting == 'golden_hour': ctr += 0.005
    elif is_light and lighting == 'overcast':    ctr += 0.003
    elif is_colorful and lighting == 'natural':  ctr += 0.011
    elif is_colorful and lighting == 'studio':   ctr += 0.008
    elif is_colorful and lighting == 'overcast': ctr -= 0.003

    # 3. Plagg + stil (context match)
    outerwear = {'jacket', 'coat', 'windbreaker', 'parka'}
    tops_casual = {'hoodie', 'zip-up hoodie', 'sweatshirt'}

    if garment_type in tops_casual and style == 'urban_outdoor':        ctr += 0.012
    elif garment_type in tops_casual and style == 'streetwear':         ctr += 0.011
    elif garment_type in tops_casual and style == 'lifestyle_indoor':   ctr += 0.006
    elif garment_type in tops_casual and style == 'studio_minimal':     ctr += 0.004
    elif garment_type in ('t-shirt', 'polo') and style == 'studio_minimal':   ctr += 0.010
    elif garment_type in ('t-shirt', 'polo') and style == 'casual_lifestyle': ctr += 0.009
    elif garment_type in ('t-shirt', 'polo') and style == 'streetwear':       ctr += 0.007
    elif garment_type in outerwear and style == 'lifestyle_outdoor':    ctr += 0.011
    elif garment_type in outerwear and style == 'urban_outdoor':        ctr += 0.009
    elif garment_type in outerwear and style == 'studio_minimal':       ctr += 0.005
    elif garment_type in ('jeans', 'trousers') and style == 'casual_lifestyle': ctr += 0.008
    elif garment_type in ('jeans', 'trousers') and style == 'urban_outdoor':   ctr += 0.006
    elif garment_type == 'shorts' and style == 'casual_lifestyle':      ctr += 0.009
    elif garment_type == 'shorts' and style == 'lifestyle_outdoor':     ctr += 0.008

    # 4. Bakgrund
    if background in ('studio_white', 'studio_grey'):                                             ctr += 0.006
    elif background == 'neutral_wall':                                                            ctr += 0.004
    elif background in ('urban_street', 'graffiti_wall') and garment_type in tops_casual | outerwear: ctr += 0.007
    elif background in ('urban_street', 'graffiti_wall') and garment_type in ('t-shirt', 'polo'): ctr += 0.004
    elif background in ('nature_outdoor', 'park') and garment_type in outerwear:                  ctr += 0.006
    elif background == 'busy_pattern':                                                            ctr -= 0.007

    # 5. Expression (emotional appeal)
    if gender == 'male':
        exp_bonus = {'confident': 0.007, 'serious': 0.005, 'focused': 0.004,
                     'smiling': 0.003, 'neutral': 0.002}.get(expression, 0.002)
    elif gender == 'female':
        exp_bonus = {'smiling': 0.008, 'confident': 0.007, 'focused': 0.005,
                     'serious': 0.004, 'neutral': 0.002}.get(expression, 0.002)
    else:  # unisex
        exp_bonus = {'confident': 0.004, 'neutral': 0.004}.get(expression, 0.002)
    ctr += exp_bonus

    # 6. Pose
    if pose == 'dynamic':                                                          ctr += 0.006
    elif pose == 'walking':                                                        ctr += 0.005
    elif pose == 'action' and garment_type in tops_casual | outerwear:            ctr += 0.006
    elif pose == 'casual':                                                         ctr += 0.003
    elif pose == 'standing':                                                       ctr += 0.002
    elif pose == 'sitting' and style == 'lifestyle_indoor':                        ctr += 0.004

    # 7. Vinkel
    if angle == '3/4':    ctr += 0.004
    elif angle == 'front': ctr += 0.002
    elif angle == 'side':  ctr -= 0.001
    elif angle == 'back' and garment_type in tops_casual | outerwear: ctr += 0.003

    # 8. Realistiskt brus (normalfördelat)
    ctr += random.gauss(0, noise_level)

    return round(max(0.005, min(0.08, ctr)), 4)


print('Formel definierad.')
# Out:
# Formel definierad.

# %% [markdown]
# ## Snabbtest – extremfall utan brus

# %%
cases = [
    ('OPTIMAL dark hoodie',
     dict(garment_type='hoodie', color='dark', fit='loose', gender='male',
          style='urban_outdoor', lighting='golden_hour', background='graffiti_wall',
          pose='dynamic', expression='confident', angle='3/4', noise_level=0)),
    ('OPTIMAL navy coat',
     dict(garment_type='coat', color='navy', fit='regular', gender='female',
          style='lifestyle_outdoor', lighting='golden_hour', background='nature_outdoor',
          pose='walking', expression='smiling', angle='3/4', noise_level=0)),
    ('SUBOPTIMAL burgundy jeans',
     dict(garment_type='jeans', color='burgundy', fit='tight', gender='male',
          style='studio_minimal', lighting='overcast', background='busy_pattern',
          pose='standing', expression='neutral', angle='side', noise_level=0)),
]

for name, params in cases:
    ctr = calculate_ctr(**params)
    print(f'{name:<30}: {ctr*100:.2f}%')
# Out:
# OPTIMAL dark hoodie           : 7.40%
# OPTIMAL navy coat             : 7.30%
# SUBOPTIMAL burgundy jeans     : 1.30%

# %% [markdown]
# ## Generera 5000 produkter

# %%
def make_product():
    g  = random.choice(GARMENT_TYPES)
    c  = random.choice(COLORS)
    f  = random.choice(FITS)
    ge = random.choice(GENDERS)
    st = random.choice(STYLES)
    li = random.choice(LIGHTINGS)
    bg = random.choice(BACKGROUNDS)
    po = random.choice(POSES)
    ex = random.choice(EXPRESSIONS)
    an = random.choice(ANGLES)
    return {
        'garment_type': g, 'color': c, 'fit': f, 'gender': ge,
        'style': st, 'lighting': li, 'background': bg,
        'pose': po, 'expression': ex, 'angle': an,
        'ctr': calculate_ctr(g, c, f, ge, st, li, bg, po, ex, an),
        'impressions': random.randint(1000, 5000)
    }

products = [make_product() for _ in range(5000)]
df = pd.DataFrame(products)

print(f'Genererade {len(df)} produkter')
print(df['ctr'].describe())
# Out:
# Genererade 5000 produkter
# count    5000.000000
# mean        0.047037
# std         0.011482
# min         0.007000
# 25%         0.039100
# 50%         0.047200
# 75%         0.055200
# max         0.080000
# Name: ctr, dtype: float64

# %% [markdown]
# ## Spara

# %%
OUTPUT_PATH.parent.mkdir(parents=True, exist_ok=True)
with open(OUTPUT_PATH, 'w') as f:
    json.dump(df.to_dict('records'), f, indent=2)

print(f'Sparad: {OUTPUT_PATH.resolve()}')
print(f'Antal: {len(df)}')
print(f'CTR range: {df["ctr"].min()*100:.1f}% – {df["ctr"].max()*100:.1f}%')
print(f'Medel CTR: {df["ctr"].mean()*100:.2f}%')
# Out:
# Sparad: /Users/edvinrunhellen/Documents/MAI24HA/Exjobb/skejl/data/input/ctr_dataset.json
# Antal: 5000
# CTR range: 0.7% – 8.0%
# Medel CTR: 4.70%
